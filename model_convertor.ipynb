# %%
from torch import nn
import torch.utils.model_zoo as model_zoo
import torch.onnx

model = torch.hub.load('WongKinYiu/yolov7', r"C:\Users\rctuh\Downloads\DP_objectD_yolov7-20240215T211221Z-001\DP_objectD_yolov7\weights\best.pt",
                        force_reload=True, trust_repo=True)
model.load_state_dict(torch.load(r"C:\Users\rctuh\Downloads\DP_objectD_yolov7-20240215T211221Z-001\DP_objectD_yolov7\weights\best.pt", map_location='cpu')['state_dict'])
model.eval()
# Out:
# Downloading: "https://github.com/WongKinYiu/yolov7/zipball/main" to C:\Users\rctuh/.cache\torch\hub\main.zip
# requirements: numpy<1.24.0,>=1.18.5 not found and is required by YOLOR, attempting auto-update...
# ---------------------------------------------------------------------------
# VersionConflict                           Traceback (most recent call last)
# File ~/.cache\torch\hub\WongKinYiu_yolov7_main\utils\general.py:110, in check_requirements(requirements, exclude)
#     109 try:
# --> 110     pkg.require(r)
#     111 except Exception as e:  # DistributionNotFound or VersionConflict if requirements not met
#
# File c:\Users\rctuh\.conda\envs\drypatch\lib\site-packages\pkg_resources\__init__.py:968, in WorkingSet.require(self, *requirements)
#     960 """Ensure that distributions matching `requirements` are activated
#     961
#     962 `requirements` must be a string or a (possibly-nested) sequence
#    (...)
# ...
